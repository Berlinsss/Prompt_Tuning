# %%
# Marco F1 60%、80%数据

# %%
# !pip install transformers
# !pip install torchmetrics

# %%
import os
os.chdir('/content/drive/MyDrive/Dissertation/t_experiment')

# %%
# !python Prompt-tuning_1.8%.py

# %%
# !python Prompt-tuning_1.2%.py
